# %%
import requests

data_url = "https://eskom-calendar-api.shuttleapp.rs/outages/city-of-cape-town-area-9"

data_response = requests.get(data_url)

print(data_response.url)

# print the response
print(data_response.text)
